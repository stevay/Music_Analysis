# %% [markdown]
# # Popular Music Analysis
# Looking at Billboard Hot 100 songs between 1950 - 2018
#
# For this jupyter notebook, we will be collecting songs along with their associated audio feature from Spotify

# %% [markdown]
# # Parsing JSON files related to Billboard Top 100
#
# - go through each JSON file, and extract Billboard Top 100 data for each year, and store into a Pandas DataFrame

# %%
years = range(1950,2016)

with open('data/years/1950.json') as data_file:
    data = json.load(data_file)
    
df = pd.DataFrame(data)

for year in years:
    with open('data/years/' + str(year) + '.json') as data_file:
        data = json.load(data_file)
    
    #df = df.append(data,ignore_index=True,verify_integrity=True)
    if year == 1950:
        df = pd.DataFrame(data)
    else:
        df = df.append(data,ignore_index=True,verify_integrity=True)

#df

# %%
df.tail(5)

# %%
# pickle billboard Hot 100 tracks between 1950 - 2015
df.to_pickle("data/billboard_tracks.pkl")

# %% [markdown]
# # Using pandas to pull the Billboard Hot 100 for 2016, 2017, and 2018 from Wikipedia.com

# %%
for year in range(2016,2019):

    # pull billboard Hot 100 charts from Wikipedia
    billboard_data = pd.read_html('https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_' + \
                                  str(year),header=0)
    
    # store web scraped data into a pandas dataframe
    df_temp = pd.DataFrame(data=billboard_data[0].loc[:,['No.','Title','Artist(s)']])
    
    # rename the columns to match original dataset
    df_temp.rename(columns={'No.':'pos','Title':'title','Artist(s)':'artist'},inplace=True)
    
    # insert year column
    df_temp['year'] = pd.Series(int(year),index=df_temp.index)
    
    if year == 2016:
        df_wiki = df_temp
    else:
        df_wiki = df_wiki.append(df_temp,ignore_index=True,verify_integrity=True)
        
    # remove quotations(") from song titles
    df_wiki['title'] = df_wiki['title'].str.replace('"','')
    
    # update songs manually to get lyrics
    df_wiki.iloc[68,1] = 'Down In the DM'
    df_wiki.iloc[87,1] = 'Watch Me (Whip / Nae Nae)'
    df_wiki.iloc[125,2] = 'Zayn & Taylor Swift'
    df_wiki.iloc[127,1] = 'ISpy'
    df_wiki.iloc[198,1] = 'Look At Me'
    df_wiki.iloc[218,2] = 'Khalid & Normani'
    df_wiki.iloc[239,2] = 'The Weeknd & Kendrick Lamar'
    df_wiki.iloc[246,2] = 'Kendrick Lamar & SZA'
    df_wiki.iloc[249,1] = 'Love.'
    df_wiki.iloc[278,2] = 'Jay Rock, Kendrick Lamar, Future & James Blake'
    df_wiki.iloc[289,2] = 'Nicky Jam & J Balvin'
    df_wiki.iloc[292,1] = 'Dura (Remix)'

# %%
df_wiki.head()

# %%
df_wiki.loc[df_wiki['title'] == "Dura (Remix)"]

# %%
# manually update 
df_wiki.iloc[292,1] = 'Dura (Remix)'

# %%
# songs without lyrics from PyLyrics: 256, 262, 280, 290

# %% [markdown]
# ## helper function to get tags associated with each artist + count dupes in lyrics

# %%
import musicbrainzngs as mb

mb.set_useragent("billboard-top-100-lyrics", "1.0", "schaich.kevin@gmail.com")

def get_tags(artist):
    artist_id = mb.search_artists(artist)['artist-list'][0]['id']
    tags = mb.get_artist_by_id(artist_id, includes=["tags"])['artist']["tag-list"]

    return [tag['name'] for tag in tags]

def count_dupes(lyrics):
    list = lyrics.split("\n")
    count = 0
    seen = set()
    for item in list:
        if item in seen:
            count += 1
        else:
            seen.add(item)
    return count

# %% [markdown]
# ## obtain + clean features for Billboard Hot 100 songs between 2016 and 2018

# %%
from PyLyrics import *
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textstat.textstat import textstat as ts
import re

billboard_attr_list = []
sent_analyzer = SentimentIntensityAnalyzer()

for index, row in df_wiki.iterrows():
    
    data = {}
    artist = row['artist']
    title = row['title']

    # clean up artist / title data
    artist = re.sub(r' feat..*', r'', artist)
    artist = re.sub(r' ft..*', r'', artist)
    artist = re.sub(r' featuring..*', r'', artist)
    artist = re.sub(r' and..*',r'',artist)
    artist = re.sub(r',..*',r'',artist)

    # update artist name in dataframe
    df_wiki.loc[index,['artist']] = artist

    if index == 278:
        df_wiki.iloc[278,2] = 'Jay Rock, Kendrick Lamar, Future & James Blake'
        artist = 'Jay Rock, Kendrick Lamar, Future & James Blake'

    # getting genre tags per artist
    try: 
        data['tags'] = get_tags(artist)
        #print('get_tags works')
    except:
        try:
            #artist_name = 'Meghan Trainor'
            query = "artist:" + artist
            search_results = spotify_object.search(query,limit=1,type='artist')

            # get the genre
            data['tags'] = search_results['artists']['items'][0]['genres']
            #print('spotify API works')
        except:
            print('Issue with getting tags for artist: ' + str(artist))


    # PyLyrics library for finding lyrics
    try: 
        lyrics = PyLyrics.getLyrics(artist,title) #Print the lyrics directly
        lyrics_repl = lyrics.replace("\n",". ")
        data['lyrics'] = lyrics
        
        # sentiment analysis with VADER
        data['sentiment'] = sent_analyzer.polarity_scores(lyrics_repl)
        
        # functions that rate the lyric complexity
        data['f_k_grade'] = ts.flesch_kincaid_grade(lyrics_repl)
        data['flesch_index'] = ts.flesch_reading_ease(lyrics_repl)
        data['fog_index'] = ts.gunning_fog(lyrics_repl)
        data['difficult_words'] = ts.difficult_words(lyrics_repl)
        data['num_syllables'] = ts.syllable_count(lyrics_repl)
        data['num_words'] = ts.lexicon_count(lyrics_repl, True)
        data['num_lines'] = ts.sentence_count(lyrics_repl)
        
        # count dupes in lyrics
        data['num_dupes'] = count_dupes(lyrics)
        
    except:
        print('Issue with getting lyrics for track: ' + str(title) + ' by ' + str(artist))

    billboard_attr_list.append(data)

df_3 = pd.DataFrame(billboard_attr_list)
df_3 = pd.concat([df_wiki,df_3],axis=1,sort=None)

# %% [markdown]
# # Pickle DataFrame of Billboard Hot 100 songs between 2016 and 2018

# %%
# pickle billboard hot 100 for years 2016 - 2018
#df_3.to_pickle("data/billboard_tracks_2016_2018.pkl")

# %%
df_3.loc[df_3['lyrics'].isna()]

# %% [markdown]
# ## connecting to Spotify API with spotipy

# %%
import os
import sys
import json
from json.decoder import JSONDecodeError
import webbrowser
import spotipy
import spotipy.util as util
from pprint import pprint

# visualization libraries
import seaborn as sns  
import matplotlib.pyplot as plt
from matplotlib import style
% matplotlib inline

import pandas as pd
import numpy as np

import fuzzyset

from collections import Counter

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# User ID: stevay?si=yNi65NanRZeIRXlu0Gjobw

# %%
username = sys.argv[1]
username
# Out:
# '-f'

# %%
try: 
    token = util.prompt_for_user_token(username,
                                       scope=None,
                                       client_id = '39cc01d4b4a544ebad4e813e7190e606',
                                       client_secret = '21e5aa26f17247bcae6d6aeba252a49f',
                                       redirect_uri='http://google.com/')
except:
    os.remove(f".cache-{username}")
    token = util.prompt_for_user_token(username,
                                       scope=None,
                                       client_id = '39cc01d4b4a544ebad4e813e7190e606',
                                       client_secret = '21e5aa26f17247bcae6d6aeba252a49f',
                                       redirect_uri='http://google.com/')
    

# create spotify object
spotify_object = spotipy.Spotify(auth=token)
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=39cc01d4b4a544ebad4e813e7190e606&response_type=code&redirect_uri=http%3A%2F%2Fgoogle.com%2F in your browser
#
#
# Enter the URL you were redirected to: https://www.google.com/?code=AQDCH5TnMjw4SPA0km0UJUnbB7LVTK7rurcbJJnW-5MXub1nUXDz40kyODKfUA9Cjx89e4zkOQyZYeHg7j-SJ8v5Ytur5k9fidr1X4BWogz3PYh_6Gyp3G2Xmy_hIGAthSlIYbgX3ha7exFYh_94z6djJPViKyrDNhIqjSeGTxUsVXjrIMcQAxy9

# %%
# useful code to print JSON from spotify
# print(json.dumps(VARIABLE, sort_keys=True,indent=4))

# %% [markdown]
# # Helper function to search for specific tracks of artists on Spotify and pull features of interest (e.g. track_id)

# %%
def get_spotify_track_id(df):
    '''given a DataFrame with columns 'artist' and 'title', use Spotify API to look up:
    'track_name'
    'track_id'
    'track_preview_url'
    'track_album_cover_art'
    
    '''
    
    
    # iterate through list of artists/track names in dataset
    spotify_list_data = []

    for index, row in df.iterrows():
        #print(row['artist'] + ' - ' + row['title'])
        data = {}

        # define query
        query = 'artist:' + str(row['artist'] + ' track:' + str(row['title'].replace("'",'')))

        # search with Spotipy / Spotify API / spotify_object
        search_result = spotify_object.search(query, limit=5,type='track')

        if len(search_result['tracks']['items']) == 0:
            data['track_name'] = None
            data['track_id'] = None
            data['track_preview_url'] = None
            data['track_album_cover_art'] = None

        else:
            # list to store tracks from search results
            temp_list = []

            # iterate through all results to find the right track
            for i in range(len(search_result['tracks']['items'])):

                temp_list.append(search_result['tracks']['items'][i]['name'])

            # initiate new fuzzy match set
            fz = fuzzyset.FuzzySet()

            # Create a list of terms we would like to match against in a fuzzy way
            for i in temp_list:

                fz.add(i)

            # find index to pull results from Spotify
            correct_index = temp_list.index(fz.get(str(row['title']))[0][1])

            # save results
            data['track_name'] = search_result['tracks']['items'][correct_index]['name']
            data['track_id'] = search_result['tracks']['items'][correct_index]['id']
            data['track_preview_url'] = search_result['tracks']['items'][correct_index]['preview_url']
            data['track_album_cover_art'] = search_result['tracks']['items'][correct_index]['album']['images'][0]['url']

        # append to list
        spotify_list_data.append(data)


    # create new DataFrame based on results from Spotify
    df_temp = pd.DataFrame(spotify_list_data)
    
    return df_temp

# %%
df_2 = get_spotify_track_id(df) # get spotify track IDs for Billboard Hot 100 songs between 1950 - 2015
df_4 = get_spotify_track_id(df_3) # get spotify track IDs for Billboard Hot 100 songs between 2016- 2018
# Out:
# retrying ...4secs
# retrying ...1secs

# %%
# missing tracks
df_4.loc[df_4['track_id'].isna()]
# Out:
#    track_album_cover_art track_id track_name track_preview_url
# 70                  None     None       None              None

# %% [markdown]
# # Use below to save pickle files

# %%
# pickle spotify track IDs
#df_2.to_pickle("data/spotify_track_ids.pkl")
#df_4.to_pickle("data/spotify_track_ids_2016_2018.pkl")

# %% [markdown]
# # Use below to load all the relevant pickle files

# %%
# load spotify track IDs (1950 - 2015)
df_2 = pd.read_pickle("data/spotify_track_ids.pkl")

# load billboard Hot 100 tracks (1950 - 2015)
df = pd.read_pickle("data/billboard_tracks.pkl")

# load billboard Hot 100 tracks (2016 - 2018)
df_3 = pd.read_pickle("data/billboard_tracks_2016_2018.pkl")

# load spotify track IDs (2016 - 2018)
df_4 = pd.read_pickle("data/spotify_track_ids_2016_2018.pkl")

# %% [markdown]
# # Use below code to manually update df_2 with spotify data

# %%
len(df_2.loc[df_2['track_name'].isna()]) # 33 songs not on Spotify
# Out:
# 33

# %%
df.iloc[78,:]
# Out:
# artist                                                Nervous Norvus
# difficult_words                                                   50
# f_k_grade                                                        4.1
# flesch_index                                                   80.28
# fog_index                                                        5.2
# lyrics             TRANSFUSION\nNervous Norvus\n\nZZZZZZOOOOOOOOO...
# num_dupes                                                         20
# num_lines                                                         40
# num_syllables                                                  479.7
# num_words                                                        345
# pos                                                               47
# sentiment          {'neg': 0.057, 'neu': 0.914, 'pos': 0.029, 'co...
# tags                                            [death by cirrhosis]
# title                                                    Transfusion
# year                                                            1956
# Name: 78, dtype: object

# %%
df_2.iloc[78,:]
# Out:
# track_album_cover_art    None
# track_id                 None
# track_name               None
# track_preview_url        None
# Name: 78, dtype: object

# %%
# update df_2 with helper function below

update_track(78,0,df_2)

# %%
# helper function to update dataframes manually
def update_track(row,index,df):
    '''
    Purpose of this helper function is to update a specified DataFrame with data pulled via the Spotify API.
    
    parameters: 
    row = which row in DataFrame to update
    index = the specific item in the Spotify API search result to update the DataFrame with
    df = the DataFrame to update
    '''

    # get the track name
    df.iloc[row,2] = search_results_test['tracks']['items'][index]['name']

    # get the track ID
    df.iloc[row,1] = search_results_test['tracks']['items'][index]['id']

    # preview url
    df.iloc[row,3] = search_results_test['tracks']['items'][index]['preview_url']

    # album cover art
    df.iloc[row,0] = search_results_test['tracks']['items'][index]['album']['images'][0]['url']

# %% [markdown]
# ## Script to gather Spotify Audio Features for each track

# %%
#track_audio_features_list = []
#counter = 0
track_ids = []
#track_features_dict = {} 

for index, row in df_2.iterrows():
    #print(row['track_id'])
    
    track_ids.append(row['track_id'])
    
    if len(track_ids) == 50 or index == (len(df_2)-1):
        track_features = spotify_object.audio_features(tracks=[track_ids])
        track_features_df_temp = pd.DataFrame(track_features)
        df_3.append()
        
        if index == 49:
            df_3 = track_features_df_temp
        else:
            df_3 = df_3.append(track_features_df_temp,ignore_index=False,verify_integrity=True)
        track_ids = []

# %% [markdown]
# # Use below to manually search track content in Spotify

# %%
# use 98\u00ba for 98 Degrees...

# %%
artist_name = 'Nicky Jam'
track_name = "X"

# %%
#track_name = '4gB7HrYHbJVJ5RFOjxmoq4'
#query = "artist:" + artist_name + " track:" + track_name # define filters
#query = " track:" + track_name # define filters
search_results_test = spotify_object.search(query,limit=5,type='track')

# %%
len(search_results_test['tracks']['items'])
# Out:
# 0

# %%
print(json.dumps(search_results_test,sort_keys=True,indent=4))
# Out:
# {
#     "tracks": {
#         "href": "https://api.spotify.com/v1/search?query=spotify%3Atrack%3A4gB7HrYHbJVJ5RFOjxmoq4&type=track&market=US&offset=0&limit=5",
#         "items": [],
#         "limit": 5,
#         "next": null,
#         "offset": 0,
#         "previous": null,
#         "total": 0
#     }
# }

# %%
# get the track name

search_results_test['tracks']['items'][1]['name']
# Out:
# 'X'

# %%
# get the track ID

search_results_test['tracks']['items'][0]['id']
# Out:
# '6KBYefIoo7KydImq1uUQlL'

# %%
# preview url

search_results_test['tracks']['items'][0]['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/cab6e91217590b37cc254585f3f951c5a5280375?cid=39cc01d4b4a544ebad4e813e7190e606'

# %%
# album cover art

search_results_test['tracks']['items'][0]['album']['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/9c1ba089336e2b67a7bb8d385bada87481852ede'

# %% [markdown]
# # combine data frames together with pandas '.concat' function
#
# Combine the following:
# - df + df_2
# - df_3 + df_4

# %%
df_final = pd.concat([df,df_2],axis=1,sort=None)
df_half_2 = pd.concat([df_3,df_4],axis=1,sort=None)
df_final = df_final.append(df_half_2,ignore_index=True,verify_integrity=True)

# pickle the final dataframe
#df_final.to_pickle("data/billboard_tracks_1950_2018_no_audio_features.pkl")
# Out:
# /Users/auyeus/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# # Load pickle file of all songs without Spotify audio features

# %%
# load spotify track IDs (1950 - 2018)
df_final = pd.read_pickle("data/billboard_tracks_1950_2018_no_audio_features.pkl")

# %% [markdown]
# # songs missing from Spotify (34 songs total)

# %%
# songs that are missing from Spotify (34 songs total)
df_final.loc[df_final['track_id'].isna(),:]
# Out:
#                artist  difficult_words  f_k_grade  flesch_index  fog_index  \
# 78     Nervous Norvus             50.0        4.1         80.28       5.20
# 91        Jane Powell              2.0        0.9         99.23       4.40
# 180      Kathy Linden              6.0        2.1         90.77       4.40
# 391       Ray Charles              5.0        1.3        103.63       6.00
# 411   Dave Clark Five             13.0        1.3         98.21       4.80
# 431   Dave Clark Five              4.0        1.3         98.21       4.80
# 433   Dave Clark Five              8.0        0.5        105.66       5.20
# 483   Dave Clark Five              3.0       -3.0        125.62       4.00
# 501   Dave Clark Five              7.0        2.9         94.15       6.40
# 603         Tremeloes              9.0        1.3         98.21       4.80
# 1455        Joe Walsh              4.0       -0.3        107.69       4.40
# 1520   John Schneider             12.0        1.3         98.21       4.80
# 1626       Eddy Grant             24.0        2.5         89.75       4.80
# 1627     Thomas Dolby             28.0        1.7         91.78       4.00
# 1637       Toni Basil             16.0        1.7         97.20       5.20
# 1747       Irene Cara             19.0        2.1         90.77       4.40
# 1920   Paul McCartney              9.0        0.5        100.24       4.00
# 2062     Paul Carrack              8.0       -0.7        108.70       4.00
# 2360          Dr. Dre             86.0        2.1         96.18       5.60
# 2388          Dr. Dre             85.0        1.7         97.20       5.20
# 2517    Janet Jackson             29.0        2.1         90.77       4.40
# 2600          Aaliyah              8.0        0.1        106.67       4.80
# 2611    Janet Jackson             29.0        2.1         90.77       4.40
# 2714       Puff Daddy             66.0        0.5        100.24       4.00
# 2807            Jay-Z             66.0        1.7         97.20       5.20
# 2917            Jay-Z             61.0        0.9         99.23       4.40
# 2936     Mariah Carey             37.0        1.7         91.78       4.00
# 2970      Truth Hurts             43.0        1.3         98.21       4.80
# 2988   Angie Martinez             50.0        2.1         96.18       5.60
# 3165            Jay-Z             47.0        1.3         98.21       4.80
# 3577            Jay-Z             92.0        1.3         98.21       4.80
# 3603            Jay-Z             67.0        2.5         89.75       4.80
# 3817            Jay Z             70.0        1.3         98.21       4.80
# 4098          Beyoncé             26.0        0.9         99.12       4.97
#
#                                                  lyrics  num_dupes  num_lines  \
# 78    TRANSFUSION\nNervous Norvus\n\nZZZZZZOOOOOOOOO...       20.0       40.0
# 91    I give to you and you give to me\nTrue love, t...        1.0        8.0
# 180   Bomp, bomp, bomp, bomp-bomp-bomp\nBomp, bomp, ...       17.0       22.0
# 391   Take these chains from my heart and set me fre...       10.0       17.0
# 411   You say that you love (Say you love me)\nAll o...       27.0       40.0
# 431   It's right that I should care about you,\nAnd ...        8.0       16.0
# 433   Whoa, can't you see that she's mine\nWe've bee...       14.0       29.0
# 483   Here they come again, mmmm-mm-mm\nCatch us if ...       20.0       24.0
# 501   Come on (come on let me show you where it's at...       18.0       28.0
# 603   Oh, don't it hurt deep inside \nTo see someone...        7.0       20.0
# 1455  We get up early and we work all day \nWe put o...        7.0       16.0
# 1520  Its now or never; Come hold me tight.\nKiss me...        5.0       20.0
# 1626  Boy! \nBoy!\n\nNow in the street, there is vio...       32.0       48.0
# 1627  Ha!\n\nIt's poetry in motion\nShe turned her t...       21.0       46.0
# 1637  Oh Mickey, you're so fine\nYou're so fine, you...       51.0       61.0
# 1747  Well, what's this new feeling coming out of th...        9.0       18.0
# 1920  Ooh ooh what do you do \nNo one else can dance...       21.0       41.0
# 2062  Cab fare to nowhere\nIs what you are\nA white ...       29.0       39.0
# 2360  Snoop Dogg and Dr. Dre:\nOne, two, three, and ...       15.0       81.0
# 2388  Yeah, hell yeah\nHa, know what I'm sayin'?\n\n...       21.0       83.0
# 2517  Excuse me...\nHa ha ha\nThere we go\n\nI've se...       25.0       44.0
# 2600  If your girl only knew\nThat you was tryin' to...       20.0       33.0
# 2611  Excuse me...\nHa ha ha\nThere we go\n\nI've se...       25.0       44.0
# 2714  Uh-huh yeah (2x)\nUh uh-huh yeah (4x)\nYeah\n\...       54.0       87.0
# 2807  Take the bassline out, uh huh\nJigga uh huh uh...       32.0       72.0
# 2917  Let's go\nHov!\nUh huh, Hov'\nYou, are, not, r...       39.0       90.0
# 2936  I got myself a lover\nWho loves what I like\nW...       53.0       90.0
# 2970  (Verse 1: Truth Hurts)\nHe breaks, me down, he...       18.0       53.0
# 2988  (Lil' Mo) Yeaaaaaaaaaaayyyyy!!!\n(Angie M) Oh ...       34.0       85.0
# 3165  \nUh, uh, whooo, the bounce is back\nUh, uh, u...       16.0       67.0
# 3577  Yeah\nYeah, I'm up at Brooklyn, now I'm down i...       33.0       84.0
# 3603  Mr Hudson\nLet's dance in style\nLet's dance f...       37.0       82.0
# 3817  You'd take the clothes off my back and I let y...       49.0       95.0
# 4098  Sorry, I ain't sorry\nSorry, I ain't sorry\nI ...       33.0       67.0
#
#       num_syllables  num_words  pos  \
# 78            479.7      345.0   47
# 91             60.3       52.0   86
# 180           184.5      140.0   90
# 391           204.3      181.0   92
# 411           342.9      280.0   23
# 431           140.4      116.0   63
# 433           283.5      251.0   67
# 483           129.6      137.0   54
# 501           355.5      309.0   80
# 603           183.6      155.0   45
# 1455          114.3      108.0   99
# 1520          190.8      156.0   82
# 1626          440.1      347.0   22
# 1627          319.5      249.0   23
# 1637          630.9      509.0   36
# 1747          152.1      118.0   69
# 1920          276.3      236.0   92
# 2062          229.5      213.0   83
# 2360          854.1      729.0   11
# 2388          842.4      700.0   53
# 2517          378.9      303.0   29
# 2600          262.8      234.0   69
# 2611          378.9      303.0   84
# 2714          595.8      495.0   47
# 2807          711.0      617.0   89
# 2917          729.9      623.0   56
# 2936          572.4      453.0   80
# 2970          475.2      413.0   40
# 2988          891.0      769.0   69
# 3165          615.6      528.0   91
# 3577          835.2      670.0   21
# 3603          755.1      574.0   50
# 3817          837.0      701.0   22
# 4098          513.0      411.0   71
#
#                                               sentiment  \
# 78    {'neg': 0.057, 'neu': 0.914, 'pos': 0.029, 'co...
# 91    {'neg': 0.0, 'neu': 0.648, 'pos': 0.352, 'comp...
# 180   {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compou...
# 391   {'neg': 0.056, 'neu': 0.632, 'pos': 0.312, 'co...
# 411   {'neg': 0.022, 'neu': 0.71, 'pos': 0.268, 'com...
# 431   {'neg': 0.023, 'neu': 0.727, 'pos': 0.25, 'com...
# 433   {'neg': 0.084, 'neu': 0.805, 'pos': 0.111, 'co...
# 483   {'neg': 0.039, 'neu': 0.936, 'pos': 0.025, 'co...
# 501   {'neg': 0.007, 'neu': 0.896, 'pos': 0.097, 'co...
# 603   {'neg': 0.099, 'neu': 0.82, 'pos': 0.081, 'com...
# 1455  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...
# 1520  {'neg': 0.115, 'neu': 0.748, 'pos': 0.138, 'co...
# 1626  {'neg': 0.074, 'neu': 0.877, 'pos': 0.05, 'com...
# 1627  {'neg': 0.031, 'neu': 0.832, 'pos': 0.137, 'co...
# 1637  {'neg': 0.043, 'neu': 0.748, 'pos': 0.209, 'co...
# 1747  {'neg': 0.069, 'neu': 0.823, 'pos': 0.107, 'co...
# 1920  {'neg': 0.06, 'neu': 0.807, 'pos': 0.133, 'com...
# 2062  {'neg': 0.027, 'neu': 0.929, 'pos': 0.044, 'co...
# 2360  {'neg': 0.123, 'neu': 0.68, 'pos': 0.197, 'com...
# 2388  {'neg': 0.153, 'neu': 0.726, 'pos': 0.121, 'co...
# 2517  {'neg': 0.018, 'neu': 0.625, 'pos': 0.358, 'co...
# 2600  {'neg': 0.129, 'neu': 0.745, 'pos': 0.126, 'co...
# 2611  {'neg': 0.018, 'neu': 0.625, 'pos': 0.358, 'co...
# 2714  {'neg': 0.203, 'neu': 0.672, 'pos': 0.125, 'co...
# 2807  {'neg': 0.138, 'neu': 0.798, 'pos': 0.064, 'co...
# 2917  {'neg': 0.101, 'neu': 0.723, 'pos': 0.176, 'co...
# 2936  {'neg': 0.01, 'neu': 0.795, 'pos': 0.196, 'com...
# 2970  {'neg': 0.108, 'neu': 0.737, 'pos': 0.155, 'co...
# 2988  {'neg': 0.059, 'neu': 0.842, 'pos': 0.099, 'co...
# 3165  {'neg': 0.077, 'neu': 0.791, 'pos': 0.132, 'co...
# 3577  {'neg': 0.057, 'neu': 0.773, 'pos': 0.17, 'com...
# 3603  {'neg': 0.139, 'neu': 0.738, 'pos': 0.123, 'co...
# 3817  {'neg': 0.156, 'neu': 0.712, 'pos': 0.132, 'co...
# 4098  {'neg': 0.095, 'neu': 0.726, 'pos': 0.18, 'com...
#
#                                                    tags  \
# 78                                 [death by cirrhosis]
# 91                            [actress, dancer, singer]
# 180                                     [goodbye jimmy]
# 391   [american, blues, classic pop and rock, countr...
# 411                              [british, english, uk]
# 431                              [british, english, uk]
# 433                              [british, english, uk]
# 483                              [british, english, uk]
# 501                              [british, english, uk]
# 603        [british, classic pop and rock, english, uk]
# 1455  [american, américain, composer, compositeur, g...
# 1520                                            [actor]
# 1626  [british, classic pop and rock, english, guyan...
# 1627  [80s synthpop, british, english, rock and indi...
# 1637  [80s, alternative, dance, pop, rock, rock and ...
# 1747                             [classic pop and rock]
# 1920  [00s, 60s, 70s, 80s, 90s, british, classic pop...
# 2062              [blue-eyed soul, pop rock, soft rock]
# 2360  [classic pop and rock, g-funk, gangsta rap, ha...
# 2388  [classic pop and rock, g-funk, gangsta rap, ha...
# 2517  [dance, janet jackson escapade, janet-jackson,...
# 2600  [death by plane crash, hip hop, hip hop rnb an...
# 2611  [dance, janet jackson escapade, janet-jackson,...
# 2714                                          [hip-hop]
# 2807  [east coast hip hop, hip hop, hip hop rnb and ...
# 2917  [east coast hip hop, hip hop, hip hop rnb and ...
# 2936  [american, girl, pop, pop and chart, rnb, whis...
# 2970                       [hip hop rnb and dance hall]
# 2988                                         [american]
# 3165  [east coast hip hop, hip hop, hip hop rnb and ...
# 3577  [east coast hip hop, hip hop, hip hop rnb and ...
# 3603  [east coast hip hop, hip hop, hip hop rnb and ...
# 3817  [east coast hip hop, hip hop, hip hop rnb and ...
# 4098  [alternative r&b, art pop, contemporary pop, c...
#
#                                 title track_album_cover_art track_id  \
# 78                        Transfusion                  None     None
# 91                          True Love                  None     None
# 180                             Billy                  None     None
# 391   Take These Chains From My Heart                  None     None
# 411                     Glad All Over                  None     None
# 431                           Because                  None     None
# 433     Can't You See That She's Mine                  None     None
# 483               Catch Us If You Can                  None     None
# 501               I Like It Like That                  None     None
# 603                 Silence Is Golden                  None     None
# 1455                   All Night Long                  None     None
# 1520                It's Now Or Never                  None     None
# 1626                  Electric Avenue                  None     None
# 1627      She Blinded Me With Science                  None     None
# 1637                           Mickey                  None     None
# 1747                       Breakdance                  None     None
# 1920                    Spies Like Us                  None     None
# 2062                Don't Shed A Tear                  None     None
# 2360          Nuthin' But A "G" Thang                  None     None
# 2388                          Dre Day                  None     None
# 2517                          Runaway                  None     None
# 2600           If Your Girl Only Knew                  None     None
# 2611                          Runaway                  None     None
# 2714                     Come With Me                  None     None
# 2807                  Hard Knock Life                  None     None
# 2917              I Just Wanna Love U                  None     None
# 2936                         Loverboy                  None     None
# 2970                        Addictive                  None     None
# 2988                   If I could Go!                  None     None
# 3165                   Change Clothes                  None     None
# 3577             Empire State of Mind                  None     None
# 3603                    Young Forever                  None     None
# 3817                       Holy Grail                  None     None
# 4098                            Sorry                  None     None
#
#      track_name track_preview_url  year
# 78         None              None  1956
# 91         None              None  1956
# 180        None              None  1958
# 391        None              None  1963
# 411        None              None  1964
# 431        None              None  1964
# 433        None              None  1964
# 483        None              None  1965
# 501        None              None  1965
# 603        None              None  1967
# 1455       None              None  1980
# 1520       None              None  1981
# 1626       None              None  1983
# 1627       None              None  1983
# 1637       None              None  1983
# 1747       None              None  1984
# 1920       None              None  1986
# 2062       None              None  1988
# 2360       None              None  1993
# 2388       None              None  1993
# 2517       None              None  1995
# 2600       None              None  1996
# 2611       None              None  1996
# 2714       None              None  1998
# 2807       None              None  1999
# 2917       None              None  2001
# 2936       None              None  2001
# 2970       None              None  2002
# 2988       None              None  2002
# 3165       None              None  2004
# 3577       None              None  2010
# 3603       None              None  2010
# 3817       None              None  2013
# 4098       None              None  2016

# %% [markdown]
# # songs missing lyrics (4 songs)

# %%
df_final.loc[df_final['lyrics'].isna()]
# Out:
#                           artist  difficult_words  f_k_grade  flesch_index  \
# 4284                Rich the Kid              NaN        NaN           NaN
# 4290                          YG              NaN        NaN           NaN
# 4308                  Nio García              NaN        NaN           NaN
# 4318  YoungBoy Never Broke Again              NaN        NaN           NaN
#
#       fog_index lyrics  num_dupes  num_lines  num_syllables  num_words  pos  \
# 4284        NaN    NaN        NaN        NaN            NaN        NaN   57
# 4290        NaN    NaN        NaN        NaN            NaN        NaN   63
# 4308        NaN    NaN        NaN        NaN            NaN        NaN   81
# 4318        NaN    NaN        NaN        NaN            NaN        NaN   91
#
#      sentiment                                               tags  \
# 4284       NaN  [atl hip hop, hip hop, pop, pop rap, rap, sout...
# 4290       NaN                  [drake, hip-hop, rap, rap us, yg]
# 4308       NaN                         [reggaeton flow, tropical]
# 4318       NaN                                       [trap music]
#
#               title                              track_album_cover_art  \
# 4284      Plug Walk  https://i.scdn.co/image/4a05d4f5bec8e872222f9a...
# 4290       Big Bank  https://i.scdn.co/image/f8e9e3b5009829666d3e7b...
# 4308        Te Boté  https://i.scdn.co/image/bc4e0238d504046c887b30...
# 4318  Outside Today  https://i.scdn.co/image/b512dfac0b66cec52865a2...
#
#                     track_id                                      track_name  \
# 4284  1ZAyjvIk9YiD76yYy0TEG6                                       Plug Walk
# 4290  2iedgVVNKPzzAkeDBVQ6sR  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj
# 4308  4X5V0XWXYbjlq4yBuPiYfA                                         Te Bote
# 4318  3sA7HKGzcKTVscdiTCrWpX                                   Outside Today
#
#                                       track_preview_url  year
# 4284                                               None  2018
# 4290                                               None  2018
# 4308  https://p.scdn.co/mp3-preview/4f10f76774297e35...  2018
# 4318  https://p.scdn.co/mp3-preview/e862d38519014ce8...  2018

# %% [markdown]
# # Songs missing tags (2 songs)

# %%
df_final.loc[df_final['tags'].isna()]
# Out:
#                 artist  difficult_words  f_k_grade  flesch_index  fog_index  \
# 4246  Khalid & Normani             12.0        1.7         97.20       4.42
# 4301         ASAP Ferg             37.0        1.7         97.09       6.52
#
#                                                  lyrics  num_dupes  num_lines  \
# 4246  Sorry if it's hard to catch my vibe, mmm\nI ne...       18.0       49.0
# 4301  Yeah\n\nRide with the mob, alhamdulillah\nChec...       29.0       56.0
#
#       num_syllables  num_words  pos  \
# 4246          463.0      392.0   19
# 4301          562.0      451.0   74
#
#                                               sentiment tags       title  \
# 4246  {'neg': 0.153, 'neu': 0.626, 'pos': 0.221, 'co...  NaN   Love Lies
# 4301  {'neg': 0.154, 'neu': 0.796, 'pos': 0.049, 'co...  NaN  Plain Jane
#
#                                   track_album_cover_art  \
# 4246  https://i.scdn.co/image/ea0c58be347de0c1ea9a2c...
# 4301  https://i.scdn.co/image/e0d2d77ca43c5ea0f89b25...
#
#                     track_id                track_name  \
# 4246  45Egmo7icyopuzJN0oMEdk  Love Lies (with Normani)
# 4301  4dVpf9jZjcORqGTLUaeYj9                Plain Jane
#
#                                       track_preview_url  year
# 4246  https://p.scdn.co/mp3-preview/d53d5678b946219b...  2018
# 4301  https://p.scdn.co/mp3-preview/044999082327cc7c...  2018

# %% [markdown]
# # Remove songs missing lyrics

# %%
df_final_2 = df_final.drop([4284,4290,4308,4318])
df_final_2.reset_index(inplace=True, drop=True)

# %% [markdown]
# # Pickle DataFrame (without Spotify audio features)

# %%
# pickle the final dataframe, removing songs without lyrics
df_final_2.to_pickle("data/billboard_tracks_1950_2018_no_audio_features_v2.pkl")

# %%
# load dataframe, without audio features, but no missing lyrics
df_final_2 = pd.read_pickle("data/billboard_tracks_1950_2018_no_audio_features_v2.pkl")

# %% [markdown]
# # get Spotify audio features for all songs
#
# Skip songs without a Spotify track_id = will throw an error

# %%
# Script to get Spotify audio features for each track

#track_audio_features_list = []
#counter = 0
track_ids = []
#track_features_dict = {} 

for index, row in df_final_2.iterrows():
    #print(row['track_id'])
    
    if row['track_id']:
        track_ids.append(row['track_id'])

        if len(track_ids) == 50 or index == (len(df_final_2)-1):
            track_features = spotify_object.audio_features(tracks=track_ids)
            track_features_df_temp = pd.DataFrame(track_features)
            #df_3.append()

            if index == 49:
                df_audio_features = track_features_df_temp
            else:
                df_audio_features = df_audio_features.append(track_features_df_temp,ignore_index=True, \
                                                             verify_integrity=True)
            track_ids = []

# %%
df_audio_features.columns
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'track_href', 'type', 'uri',
#        'valence'],
#       dtype='object')

# %% [markdown]
# # insert tracks that are missing Spotify audio features, but have other important features (e.g. lyrics)

# %%
df_audio_features_updated = df_audio_features

# iterate through tracks that do not have Spotify audio features
for index, row in df_final_2.loc[df_final_2['track_id'].isna(),:].iterrows():
    
    # set Spotify audio features as 'None'
    line = pd.DataFrame({"acousticness": None, "analysis_url": None, "danceability":None,
                     "duration_ms":None,"energy":None,'id':None,'instrumentalness':None,
                     'key':None,'liveness':None,'loudness':None,'mode':None,'speechiness':None,
                     'tempo':None,'time_signature':None,'track_href':None,'type':None,'uri':None,
                     'valence':None}, index=[index])
    
    # insert song track in its designated index / row
    df_audio_features_updated = pd.concat([df_audio_features_updated[:index], line, df_audio_features_updated[index:]]).reset_index(drop=True)

# %%
df_audio_features_updated
# Out:
#       acousticness                                       analysis_url  \
# 0         0.903000  https://api.spotify.com/v1/audio-analysis/3k5y...
# 1         0.930000  https://api.spotify.com/v1/audio-analysis/6vSK...
# 2         0.971000  https://api.spotify.com/v1/audio-analysis/0788...
# 3         0.795000  https://api.spotify.com/v1/audio-analysis/1v52...
# 4         0.886000  https://api.spotify.com/v1/audio-analysis/2BNP...
# 5         0.910000  https://api.spotify.com/v1/audio-analysis/12WJ...
# 6         0.896000  https://api.spotify.com/v1/audio-analysis/28IB...
# 7         0.286000  https://api.spotify.com/v1/audio-analysis/4c5S...
# 8         0.923000  https://api.spotify.com/v1/audio-analysis/44ZA...
# 9         0.940000  https://api.spotify.com/v1/audio-analysis/1hVE...
# 10        0.826000  https://api.spotify.com/v1/audio-analysis/3GVy...
# 11        0.856000  https://api.spotify.com/v1/audio-analysis/7qwH...
# 12        0.971000  https://api.spotify.com/v1/audio-analysis/6Io0...
# 13        0.903000  https://api.spotify.com/v1/audio-analysis/0VLs...
# 14        0.971000  https://api.spotify.com/v1/audio-analysis/0788...
# 15        0.835000  https://api.spotify.com/v1/audio-analysis/6SYQ...
# 16        0.750000  https://api.spotify.com/v1/audio-analysis/5yzl...
# 17        0.801000  https://api.spotify.com/v1/audio-analysis/5hQ3...
# 18        0.903000  https://api.spotify.com/v1/audio-analysis/4lCq...
# 19        0.865000  https://api.spotify.com/v1/audio-analysis/4WTo...
# 20        0.968000  https://api.spotify.com/v1/audio-analysis/7o69...
# 21        0.814000  https://api.spotify.com/v1/audio-analysis/1pfN...
# 22        0.672000  https://api.spotify.com/v1/audio-analysis/5bET...
# 23        0.874000  https://api.spotify.com/v1/audio-analysis/17lA...
# 24        0.901000  https://api.spotify.com/v1/audio-analysis/1lZS...
# 25        0.935000  https://api.spotify.com/v1/audio-analysis/1yGB...
# 26        0.890000  https://api.spotify.com/v1/audio-analysis/4iyz...
# 27        0.809000  https://api.spotify.com/v1/audio-analysis/2cwT...
# 28        0.977000  https://api.spotify.com/v1/audio-analysis/049u...
# 29        0.721000  https://api.spotify.com/v1/audio-analysis/2jCG...
# ...            ...                                                ...
# 4294      0.217000  https://api.spotify.com/v1/audio-analysis/2FY7...
# 4295      0.143000  https://api.spotify.com/v1/audio-analysis/2ZxT...
# 4296      0.581000  https://api.spotify.com/v1/audio-analysis/7qiZ...
# 4297      0.023200  https://api.spotify.com/v1/audio-analysis/1XRg...
# 4298      0.073300  https://api.spotify.com/v1/audio-analysis/5WvA...
# 4299      0.065100  https://api.spotify.com/v1/audio-analysis/4dVp...
# 4300      0.173000  https://api.spotify.com/v1/audio-analysis/5Woa...
# 4301      0.113000  https://api.spotify.com/v1/audio-analysis/0OWZ...
# 4302      0.555000  https://api.spotify.com/v1/audio-analysis/0d2i...
# 4303      0.211000  https://api.spotify.com/v1/audio-analysis/4MPT...
# 4304      0.000874  https://api.spotify.com/v1/audio-analysis/51rX...
# 4305      0.191000  https://api.spotify.com/v1/audio-analysis/2dpa...
# 4306      0.084800  https://api.spotify.com/v1/audio-analysis/1co0...
# 4307      0.002140  https://api.spotify.com/v1/audio-analysis/4Ppu...
# 4308      0.570000  https://api.spotify.com/v1/audio-analysis/5tz6...
# 4309      0.103000  https://api.spotify.com/v1/audio-analysis/09ts...
# 4310      0.279000  https://api.spotify.com/v1/audio-analysis/3qN5...
# 4311      0.099700  https://api.spotify.com/v1/audio-analysis/2ZFr...
# 4312      0.556000  https://api.spotify.com/v1/audio-analysis/0JP9...
# 4313      0.083500  https://api.spotify.com/v1/audio-analysis/3XOL...
# 4314      0.036400  https://api.spotify.com/v1/audio-analysis/39N9...
# 4315      0.225000  https://api.spotify.com/v1/audio-analysis/6CTW...
# 4316      0.188000  https://api.spotify.com/v1/audio-analysis/6U2N...
# 4317      0.883000  https://api.spotify.com/v1/audio-analysis/7AFA...
# 4318      0.840000  https://api.spotify.com/v1/audio-analysis/2VIP...
# 4319      0.005850  https://api.spotify.com/v1/audio-analysis/4gB7...
# 4320      0.016800  https://api.spotify.com/v1/audio-analysis/1BuZ...
# 4321      0.040300  https://api.spotify.com/v1/audio-analysis/76cy...
# 4322      0.017900  https://api.spotify.com/v1/audio-analysis/4ipn...
# 4323      0.062200  https://api.spotify.com/v1/audio-analysis/0pqn...
#
#       danceability duration_ms  energy                      id  \
# 0            0.214      207573  0.1940  3k5ycyXX5qsCjLd7R2vphp
# 1            0.387      198000  0.0958  6vSKLIxqiYllqDd2VcGVHv
# 2            0.475      185000  0.1390  0788TdvEjGtjFVb6CTFdJH
# 3            0.703      156987  0.1970  1v52YkW75eN4RJ2EyDdQVI
# 4            0.608      194333  0.1970  2BNPXyUhq5WFpAO1Ff5yEg
# 5            0.645      174040  0.4300  12WJhNxX6EYC2rAlfVOW4d
# 6            0.778      160750  0.2910  28IBsttOK2aG9Cb4QtqhMr
# 7            0.574      172520  0.5000  4c5SQiPpwZKPs1YXm7ms0u
# 8            0.191      205707  0.2020  44ZAlAAn0bAEzUJgZky04H
# 9            0.248      242040  0.2200  1hVEHu6SemMvlYAP5MWkDj
# 10           0.527      116933  0.6330  3GVyT9fBXuEkGs1STo2WHZ
# 11           0.257      178933  0.2730  7qwHoWNqpppknFcFEJN1l2
# 12           0.286      157600  0.1490  6Io0N5BVZcK5nRaWAZjtnX
# 13           0.288      184040  0.1690  0VLsWxGXctGx9QtaHCpVEk
# 14           0.475      185000  0.1390  0788TdvEjGtjFVb6CTFdJH
# 15           0.504      190933  0.2650  6SYQwsOxHW5uUYjUpOKtIC
# 16           0.561      178867  0.3000  5yzlxi4VFO8UkxepsL0guW
# 17           0.336      152307  0.3150  5hQ3Z5zYqHKZBO0pPb16eI
# 18           0.665      176480  0.1410  4lCqxXZNpyLWlne1WSdFLh
# 19           0.238      170800  0.2070  4WToccEJeXgFNyfNPuSYCS
# 20           0.193      167327  0.1490  7o69dJfr6PU0eq7xBzUWWS
# 21           0.408      175333  0.3090  1pfNFUzZIhwPx1m9eqOlfX
# 22           0.210      182560  0.2710  5bETzPVHt11c82M57szEJV
# 23           0.708       79626  0.2850  17lAzS13sjJRyT119KjBDr
# 24           0.727      159507  0.2850  1lZSR5NKeNGuCPSTNL7BhW
# 25           0.466      158360  0.2520  1yGBGPgpGi5ua0HbHcvesQ
# 26           0.303      196373  0.1870  4iyzrJ3qIGBvG8yl5dWHQ8
# 27           0.808      160773  0.4210  2cwTVrrgHxl4gcHY4IHr18
# 28           0.402      130893  0.1590  049uxirFkHOefJ0yqPW8Kk
# 29           0.101      217267  0.4820  2jCGELICh9bYpSiJ9bl2vL
# ...            ...         ...     ...                     ...
# 4294         0.704      189467  0.6110  2FY7b99s15jUprqC0M5NCT
# 4295         0.375      196800  0.5740  2ZxTjs4EdJl4Y9YByIiNoo
# 4296         0.825      233713  0.6520  7qiZfU4dY1lWllzX7mPBI3
# 4297         0.890      233087  0.6330  1XRgIKC5TPwo7nWGyKqgG0
# 4298         0.552      260000  0.7600  5WvAo7DNuPRmk4APhdPzi8
# 4299         0.797      173600  0.8440  4dVpf9jZjcORqGTLUaeYj9
# 4300         0.674      259333  0.5060  5WoaF1B5XIEnWfmb5NZikf
# 4301         0.588      205453  0.4080  0OWZFobGSIW9GrSlQ9C5pc
# 4302         0.560      173800  0.6800  0d2iYfpKoM0QCKvcLCkBao
# 4303         0.449      228373  0.5990  4MPTj8lMMvxLwT3EwuXFop
# 4304         0.563      229670  0.7170  51rXHuKN8Loc4sUlKPODgH
# 4305         0.687      214290  0.7920  2dpaYNEQHiRxtZbfNsse99
# 4306         0.375      185200  0.8890  1co0puPTYvqAdUEjFOjne9
# 4307         0.916      219707  0.7270  4PpuH4mxL0rD35mOWaLoKS
# 4308         0.620      250173  0.5740  5tz69p7tJuGPeMGwNTxYuV
# 4309         0.707      278893  0.6320  09ts3GnICqYEU5PkQCpJK3
# 4310         0.899      214467  0.5860  3qN5qMTKyEEmiTZD38BNTT
# 4311         0.602      199627  0.8050  2ZFrEp20VO25BXYhMxh0GW
# 4312         0.921      135090  0.5370  0JP9xo3adEtGSdUEISiszL
# 4313         0.802      199560  0.5940  3XOLbusRgWC1vYKj56zFmO
# 4314         0.595      173628  0.7730  39N9RPD9MRb5WmoLzNzPeA
# 4315         0.477      213993  0.6100  6CTWathupIiDs7U4InHnDA
# 4316         0.772      242160  0.8030  6U2NuJILEOEpW2tVCuqKHb
# 4317         0.669      121887  0.3080  7AFASza1mXqntmGtbxXprO
# 4318         0.638      217120  0.3670  2VIPU72L6tIR4w8J8ap6Kp
# 4319         0.544      221800  0.7810  4gB7HrYHbJVJ5RFOjxmoq4
# 4320         0.713      332301  0.8310  1BuZAIO8WZpavWVbbq3Lci
# 4321         0.836      217947  0.5440  76cy1WJvNGJTj78UqeA5zr
# 4322         0.774      189440  0.6870  4ipnJyDU3Lq15qBAYNqlqK
# 4323         0.776      204347  0.7800  0pqnGHJpmpxLKifKRmU6WP
#
#       instrumentalness key  liveness  loudness mode  speechiness    tempo  \
# 0             0.000001   1    0.1070   -15.636    1       0.0325   86.198
# 1             0.000000   8    0.1700   -12.278    1       0.0391  167.122
# 2             0.000173   5    0.1280   -12.619    1       0.0333   86.156
# 3             0.000000   7    0.0982   -11.312    1       0.0327   82.114
# 4             0.000001   8    0.1140   -14.830    1       0.0446  123.357
# 5             0.000000   1    0.5610   -11.916    1       0.0444  132.643
# 6             0.000514   2    0.1470   -12.703    1       0.0390  107.730
# 7             0.000002  11    0.1610    -9.870    1       0.0354   77.461
# 8             0.000362   8    0.2890   -14.450    1       0.0289   92.091
# 9             0.001970   7    0.1090   -10.768    0       0.0299   71.377
# 10            0.000000  10    0.4220    -8.560    0       0.1140  183.174
# 11            0.000000   5    0.1420   -11.030    1       0.0362   90.913
# 12            0.000010   7    0.1320   -13.062    1       0.0315   91.598
# 13            0.000042   0    0.3170   -12.024    1       0.0294   71.412
# 14            0.000173   5    0.1280   -12.619    1       0.0333   86.156
# 15            0.000000   5    0.6040   -16.424    1       0.0344  136.721
# 16            0.000000   3    0.2830   -13.995    1       0.0422  109.795
# 17            0.000000   0    0.1750   -14.154    1       0.0432  202.391
# 18            0.000000   2    0.1660   -12.055    1       0.0536   75.067
# 19            0.000001   5    0.1350   -12.894    0       0.0301   97.574
# 20            0.000029  10    0.2480   -13.919    1       0.0364  171.488
# 21            0.000076   9    0.0786   -12.663    1       0.0282   90.702
# 22            0.341000   1    0.3390    -9.598    1       0.0330   61.278
# 23            0.000000   9    0.1580   -13.410    0       0.2360  131.284
# 24            0.000000   2    0.1410   -14.098    1       0.0457  120.195
# 25            0.000002   3    0.1710   -17.869    1       0.0416  140.970
# 26            0.000003   0    0.1010   -11.615    1       0.0295   90.486
# 27            0.000000   8    0.0724   -12.533    1       0.0420  122.752
# 28            0.000018   1    0.1550   -18.598    1       0.0306   67.796
# 29            0.030900   0    0.5120    -9.563    1       0.0374  166.982
# ...                ...  ..       ...       ...  ...          ...      ...
# 4294          0.000000   2    0.0812    -6.112    1       0.0409  100.000
# 4295          0.000000   7    0.1100    -5.305    1       0.0315  132.025
# 4296          0.000000   1    0.0931    -3.183    0       0.0802   95.977
# 4297          0.000343  11    0.0993    -5.475    1       0.1680  139.948
# 4298          0.000000   0    0.0865    -4.706    1       0.3420  135.702
# 4299          0.000000  11    0.0870    -5.482    1       0.2750  170.142
# 4300          0.000000   6    0.0866   -10.532    1       0.0434  145.965
# 4301          0.000000   3    0.1300    -8.662    1       0.0237   85.008
# 4302          0.000000   6    0.1160    -7.648    0       0.3210   89.391
# 4303          0.000000   1    0.3270    -4.892    1       0.0369  134.144
# 4304          0.000000   1    0.1830    -5.186    1       0.3370   82.064
# 4305          0.000000   5    0.1670    -2.749    1       0.0452  100.015
# 4306          0.000000   3    0.1360    -3.704    1       0.0991  199.669
# 4307          0.000145   1    0.1180    -6.556    1       0.0861   94.997
# 4308          0.000000   5    0.1900    -7.788    0       0.0479  100.021
# 4309          0.000011  10    0.0841    -7.031    1       0.0789   97.040
# 4310          0.000000  11    0.0836    -7.866    0       0.3440  150.001
# 4311          0.000000   7    0.1720    -6.079    1       0.0473   92.401
# 4312          0.004040   9    0.1020    -5.723    0       0.0804  128.009
# 4313          0.000004   8    0.0817    -5.728    1       0.0636  110.039
# 4314          0.001080   9    0.3340    -4.736    0       0.0549  180.073
# 4315          0.000000  11    0.1070    -5.628    0       0.1440   79.882
# 4316          0.000000   1    0.4340    -3.035    1       0.0468   94.981
# 4317          0.000000  11    0.0984   -10.068    1       0.0290   64.934
# 4318          0.000000   4    0.0999    -7.906    1       0.0266   71.957
# 4319          0.000000   6    0.1910    -6.160    0       0.0311  144.075
# 4320          0.000000   1    0.1180    -4.750    0       0.1500  173.948
# 4321          0.000000   7    0.0824    -5.975    1       0.0943   97.028
# 4322          0.000012  11    0.1280    -4.818    0       0.0584  104.959
# 4323          0.000000  10    0.0810    -4.374    0       0.1280  124.949
#
#      time_signature                                         track_href  \
# 0                 3  https://api.spotify.com/v1/tracks/3k5ycyXX5qsC...
# 1                 5  https://api.spotify.com/v1/tracks/6vSKLIxqiYll...
# 2                 3  https://api.spotify.com/v1/tracks/0788TdvEjGtj...
# 3                 3  https://api.spotify.com/v1/tracks/1v52YkW75eN4...
# 4                 4  https://api.spotify.com/v1/tracks/2BNPXyUhq5WF...
# 5                 4  https://api.spotify.com/v1/tracks/12WJhNxX6EYC...
# 6                 3  https://api.spotify.com/v1/tracks/28IBsttOK2aG...
# 7                 4  https://api.spotify.com/v1/tracks/4c5SQiPpwZKP...
# 8                 1  https://api.spotify.com/v1/tracks/44ZAlAAn0bAE...
# 9                 4  https://api.spotify.com/v1/tracks/1hVEHu6SemMv...
# 10                4  https://api.spotify.com/v1/tracks/3GVyT9fBXuEk...
# 11                4  https://api.spotify.com/v1/tracks/7qwHoWNqpppk...
# 12                4  https://api.spotify.com/v1/tracks/6Io0N5BVZcK5...
# 13                4  https://api.spotify.com/v1/tracks/0VLsWxGXctGx...
# 14                3  https://api.spotify.com/v1/tracks/0788TdvEjGtj...
# 15                4  https://api.spotify.com/v1/tracks/6SYQwsOxHW5u...
# 16                4  https://api.spotify.com/v1/tracks/5yzlxi4VFO8U...
# 17                4  https://api.spotify.com/v1/tracks/5hQ3Z5zYqHKZ...
# 18                4  https://api.spotify.com/v1/tracks/4lCqxXZNpyLW...
# 19                4  https://api.spotify.com/v1/tracks/4WToccEJeXgF...
# 20                3  https://api.spotify.com/v1/tracks/7o69dJfr6PU0...
# 21                3  https://api.spotify.com/v1/tracks/1pfNFUzZIhwP...
# 22                4  https://api.spotify.com/v1/tracks/5bETzPVHt11c...
# 23                4  https://api.spotify.com/v1/tracks/17lAzS13sjJR...
# 24                4  https://api.spotify.com/v1/tracks/1lZSR5NKeNGu...
# 25                4  https://api.spotify.com/v1/tracks/1yGBGPgpGi5u...
# 26                4  https://api.spotify.com/v1/tracks/4iyzrJ3qIGBv...
# 27                4  https://api.spotify.com/v1/tracks/2cwTVrrgHxl4...
# 28                4  https://api.spotify.com/v1/tracks/049uxirFkHOe...
# 29                3  https://api.spotify.com/v1/tracks/2jCGELICh9bY...
# ...             ...                                                ...
# 4294              4  https://api.spotify.com/v1/tracks/2FY7b99s15jU...
# 4295              3  https://api.spotify.com/v1/tracks/2ZxTjs4EdJl4...
# 4296              4  https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 4297              4  https://api.spotify.com/v1/tracks/1XRgIKC5TPwo...
# 4298              5  https://api.spotify.com/v1/tracks/5WvAo7DNuPRm...
# 4299              4  https://api.spotify.com/v1/tracks/4dVpf9jZjcOR...
# 4300              4  https://api.spotify.com/v1/tracks/5WoaF1B5XIEn...
# 4301              4  https://api.spotify.com/v1/tracks/0OWZFobGSIW9...
# 4302              4  https://api.spotify.com/v1/tracks/0d2iYfpKoM0Q...
# 4303              3  https://api.spotify.com/v1/tracks/4MPTj8lMMvxL...
# 4304              4  https://api.spotify.com/v1/tracks/51rXHuKN8Loc...
# 4305              4  https://api.spotify.com/v1/tracks/2dpaYNEQHiRx...
# 4306              4  https://api.spotify.com/v1/tracks/1co0puPTYvqA...
# 4307              4  https://api.spotify.com/v1/tracks/4PpuH4mxL0rD...
# 4308              4  https://api.spotify.com/v1/tracks/5tz69p7tJuGP...
# 4309              4  https://api.spotify.com/v1/tracks/09ts3GnICqYE...
# 4310              4  https://api.spotify.com/v1/tracks/3qN5qMTKyEEm...
# 4311              4  https://api.spotify.com/v1/tracks/2ZFrEp20VO25...
# 4312              4  https://api.spotify.com/v1/tracks/0JP9xo3adEtG...
# 4313              4  https://api.spotify.com/v1/tracks/3XOLbusRgWC1...
# 4314              4  https://api.spotify.com/v1/tracks/39N9RPD9MRb5...
# 4315              4  https://api.spotify.com/v1/tracks/6CTWathupIiD...
# 4316              4  https://api.spotify.com/v1/tracks/6U2NuJILEOEp...
# 4317              4  https://api.spotify.com/v1/tracks/7AFASza1mXqn...
# 4318              4  https://api.spotify.com/v1/tracks/2VIPU72L6tIR...
# 4319              4  https://api.spotify.com/v1/tracks/4gB7HrYHbJVJ...
# 4320              4  https://api.spotify.com/v1/tracks/1BuZAIO8WZpa...
# 4321              4  https://api.spotify.com/v1/tracks/76cy1WJvNGJT...
# 4322              4  https://api.spotify.com/v1/tracks/4ipnJyDU3Lq1...
# 4323              4  https://api.spotify.com/v1/tracks/0pqnGHJpmpxL...
#
#                 type                                   uri  valence
# 0     audio_features  spotify:track:3k5ycyXX5qsCjLd7R2vphp   0.3390
# 1     audio_features  spotify:track:6vSKLIxqiYllqDd2VcGVHv   0.2240
# 2     audio_features  spotify:track:0788TdvEjGtjFVb6CTFdJH   0.3740
# 3     audio_features  spotify:track:1v52YkW75eN4RJ2EyDdQVI   0.4690
# 4     audio_features  spotify:track:2BNPXyUhq5WFpAO1Ff5yEg   0.6390
# 5     audio_features  spotify:track:12WJhNxX6EYC2rAlfVOW4d   0.9440
# 6     audio_features  spotify:track:28IBsttOK2aG9Cb4QtqhMr   0.6950
# 7     audio_features  spotify:track:4c5SQiPpwZKPs1YXm7ms0u   0.8590
# 8     audio_features  spotify:track:44ZAlAAn0bAEzUJgZky04H   0.1810
# 9     audio_features  spotify:track:1hVEHu6SemMvlYAP5MWkDj   0.1910
# 10    audio_features  spotify:track:3GVyT9fBXuEkGs1STo2WHZ   0.9610
# 11    audio_features  spotify:track:7qwHoWNqpppknFcFEJN1l2   0.1800
# 12    audio_features  spotify:track:6Io0N5BVZcK5nRaWAZjtnX   0.2110
# 13    audio_features  spotify:track:0VLsWxGXctGx9QtaHCpVEk   0.2290
# 14    audio_features  spotify:track:0788TdvEjGtjFVb6CTFdJH   0.3740
# 15    audio_features  spotify:track:6SYQwsOxHW5uUYjUpOKtIC   0.3930
# 16    audio_features  spotify:track:5yzlxi4VFO8UkxepsL0guW   0.5630
# 17    audio_features  spotify:track:5hQ3Z5zYqHKZBO0pPb16eI   0.9380
# 18    audio_features  spotify:track:4lCqxXZNpyLWlne1WSdFLh   0.5090
# 19    audio_features  spotify:track:4WToccEJeXgFNyfNPuSYCS   0.3030
# 20    audio_features  spotify:track:7o69dJfr6PU0eq7xBzUWWS   0.1910
# 21    audio_features  spotify:track:1pfNFUzZIhwPx1m9eqOlfX   0.2570
# 22    audio_features  spotify:track:5bETzPVHt11c82M57szEJV   0.2280
# 23    audio_features  spotify:track:17lAzS13sjJRyT119KjBDr   0.7790
# 24    audio_features  spotify:track:1lZSR5NKeNGuCPSTNL7BhW   0.7590
# 25    audio_features  spotify:track:1yGBGPgpGi5ua0HbHcvesQ   0.3380
# 26    audio_features  spotify:track:4iyzrJ3qIGBvG8yl5dWHQ8   0.2300
# 27    audio_features  spotify:track:2cwTVrrgHxl4gcHY4IHr18   0.9630
# 28    audio_features  spotify:track:049uxirFkHOefJ0yqPW8Kk   0.2820
# 29    audio_features  spotify:track:2jCGELICh9bYpSiJ9bl2vL   0.0554
# ...              ...                                   ...      ...
# 4294  audio_features  spotify:track:2FY7b99s15jUprqC0M5NCT   0.2200
# 4295  audio_features  spotify:track:2ZxTjs4EdJl4Y9YByIiNoo   0.4060
# 4296  audio_features  spotify:track:7qiZfU4dY1lWllzX7mPBI3   0.9310
# 4297  audio_features  spotify:track:1XRgIKC5TPwo7nWGyKqgG0   0.4250
# 4298  audio_features  spotify:track:5WvAo7DNuPRmk4APhdPzi8   0.6390
# 4299  audio_features  spotify:track:4dVpf9jZjcORqGTLUaeYj9   0.5200
# 4300  audio_features  spotify:track:5WoaF1B5XIEnWfmb5NZikf   0.1830
# 4301  audio_features  spotify:track:0OWZFobGSIW9GrSlQ9C5pc   0.4840
# 4302  audio_features  spotify:track:0d2iYfpKoM0QCKvcLCkBao   0.3190
# 4303  audio_features  spotify:track:4MPTj8lMMvxLwT3EwuXFop   0.1650
# 4304  audio_features  spotify:track:51rXHuKN8Loc4sUlKPODgH   0.4270
# 4305  audio_features  spotify:track:2dpaYNEQHiRxtZbfNsse99   0.6710
# 4306  audio_features  spotify:track:1co0puPTYvqAdUEjFOjne9   0.8810
# 4307  audio_features  spotify:track:4PpuH4mxL0rD35mOWaLoKS   0.2010
# 4308  audio_features  spotify:track:5tz69p7tJuGPeMGwNTxYuV   0.3520
# 4309  audio_features  spotify:track:09ts3GnICqYEU5PkQCpJK3   0.3720
# 4310  audio_features  spotify:track:3qN5qMTKyEEmiTZD38BNTT   0.4920
# 4311  audio_features  spotify:track:2ZFrEp20VO25BXYhMxh0GW   0.3220
# 4312  audio_features  spotify:track:0JP9xo3adEtGSdUEISiszL   0.7110
# 4313  audio_features  spotify:track:3XOLbusRgWC1vYKj56zFmO   0.4190
# 4314  audio_features  spotify:track:39N9RPD9MRb5WmoLzNzPeA   0.7110
# 4315  audio_features  spotify:track:6CTWathupIiDs7U4InHnDA   0.3580
# 4316  audio_features  spotify:track:6U2NuJILEOEpW2tVCuqKHb   0.8530
# 4317  audio_features  spotify:track:7AFASza1mXqntmGtbxXprO   0.5200
# 4318  audio_features  spotify:track:2VIPU72L6tIR4w8J8ap6Kp   0.2190
# 4319  audio_features  spotify:track:4gB7HrYHbJVJ5RFOjxmoq4   0.5270
# 4320  audio_features  spotify:track:1BuZAIO8WZpavWVbbq3Lci   0.5840
# 4321  audio_features  spotify:track:76cy1WJvNGJTj78UqeA5zr   0.5100
# 4322  audio_features  spotify:track:4ipnJyDU3Lq15qBAYNqlqK   0.3080
# 4323  audio_features  spotify:track:0pqnGHJpmpxLKifKRmU6WP   0.6660
#
# [4324 rows x 18 columns]

# %% [markdown]
# # concatenate remaining dataframes (df_audio_features_updated + df_final_2)

# %%
df_final_set = pd.concat([df_final_2,df_audio_features_updated],axis=1,sort=None)

# %% [markdown]
# # Pickle the DataFrame (without Spotify audio features)

# %%
# pickle the final dataframe, removing songs without lyrics
#df_final_set.to_pickle("data/billboard_tracks_1950_2018_FINAL.pkl")

# load dataframe, without audio features, but no missing lyrics
df_final_set = pd.read_pickle("data/billboard_tracks_1950_2018_FINAL.pkl")

# %%
df_final_set.tail()
# Out:
#                artist  difficult_words  f_k_grade  flesch_index  fog_index  \
# 4319       Luke Combs             16.0        2.1         96.08       5.32
# 4320     Rae Sremmurd             58.0        2.2         95.98       5.97
# 4321         Dua Lipa              8.0        0.4        105.96       3.81
# 4322         J Balvin             41.0        3.3         82.20       8.58
# 4323  Imagine Dragons             16.0        1.8         96.89       4.89
#
#                                                  lyrics  num_dupes  num_lines  \
# 4319  Are you sitting at home all alone trying to fa...       22.0       42.0
# 4320  Yeah, yeah, yeah\nMike WiLL Made-It\nYeah, yea...       39.0      110.0
# 4321  You call me all friendly\nTellin' me how much ...       33.0       57.0
# 4322  Si el ritmo te lleva a mover la cabeza\nYa emp...       23.0       44.0
# 4323  First things first\nI'mma say all the words in...       31.0       49.0
#
#       num_syllables  num_words   ...     liveness loudness mode speechiness  \
# 4319          466.0      382.0   ...       0.1910   -6.160    0      0.0311
# 4320         1179.0     1014.0   ...       0.1180   -4.750    0      0.1500
# 4321          483.0      441.0   ...       0.0824   -5.975    1      0.0943
# 4322          374.0      267.0   ...       0.1280   -4.818    0      0.0584
# 4323          498.0      407.0   ...       0.0810   -4.374    0      0.1280
#
#         tempo time_signature  \
# 4319  144.075              4
# 4320  173.948              4
# 4321   97.028              4
# 4322  104.959              4
# 4323  124.949              4
#
#                                              track_href            type  \
# 4319  https://api.spotify.com/v1/tracks/4gB7HrYHbJVJ...  audio_features
# 4320  https://api.spotify.com/v1/tracks/1BuZAIO8WZpa...  audio_features
# 4321  https://api.spotify.com/v1/tracks/76cy1WJvNGJT...  audio_features
# 4322  https://api.spotify.com/v1/tracks/4ipnJyDU3Lq1...  audio_features
# 4323  https://api.spotify.com/v1/tracks/0pqnGHJpmpxL...  audio_features
#
#                                        uri  valence
# 4319  spotify:track:4gB7HrYHbJVJ5RFOjxmoq4    0.527
# 4320  spotify:track:1BuZAIO8WZpavWVbbq3Lci    0.584
# 4321  spotify:track:76cy1WJvNGJTj78UqeA5zr    0.510
# 4322  spotify:track:4ipnJyDU3Lq15qBAYNqlqK    0.308
# 4323  spotify:track:0pqnGHJpmpxLKifKRmU6WP    0.666
#
# [5 rows x 37 columns]

# %% [markdown]
# # Columns to add to final dataset
# Includes the following columns:
# - **sentiment_compound** - the compound score per VADER sentiment analysis
# - **decade** - which decade the song track is associated with (e.g. 1960s)
# - **agg_genre** - 1 of 15 genres the song track is associated with (e.g. rock)

# %%
# add a column for compound sentiment analysis (negative: < -0.05; positive: > +0.05)
sent_list = []
for i in df_final_set['sentiment']:
    sent_list.append(i['compound'])

df_final_set['sentiment_compound'] = pd.Series(sent_list,index=df_final_set.index)


# add a column to indicate decades (e.g. 1950s, 1960s, etc.)
decade_list = []
for i in df_final_set['year']:
    #print(i)
    decade_list.append(str(i)[2:3]+'0s')

df_final_set['decade'] = pd.Series(decade_list,index=df_final_set.index)

# %% [markdown]
# ### creating 15 aggregated genres

# %%
aggregate_genres = [{"rock": ["symphonic rock", "jazz-rock", "heartland rock", "rap rock", "garage rock", "folk-rock", "roots rock", "adult alternative pop rock", "rock roll", "punk rock", "arena rock", "pop-rock", "glam rock", "southern rock", "indie rock", "funk rock", "country rock", "piano rock", "art rock", "rockabilly", "acoustic rock", "progressive rock", "folk rock", "psychedelic rock", "rock & roll", "blues rock", "alternative rock", "rock and roll", "soft rock", "rock and indie", "hard rock", "pop/rock", "pop rock", "rock", "classic pop and rock", "psychedelic", "british psychedelia", "punk", "metal", "heavy metal"]},
{"alternative/indie": ["adult alternative pop rock", "alternative rock", "alternative metal", "alternative", "lo-fi indie", "indie", "indie folk", "indietronica", "indie pop", "indie rock", "rock and indie"]},
{"electronic/dance": ["dance and electronica", "electro house", "electronic", "electropop", "progressive house", "hip house", "house", "eurodance", "dancehall", "dance", "trap"]},
{"soul": ["psychedelic soul", "deep soul", "neo-soul", "neo soul", "southern soul", "smooth soul", "blue-eyed soul", "soul and reggae", "soul"]},
{"classical/soundtrack": ["classical", "orchestral", "film soundtrack", "composer"]},
{"pop": ["country-pop", "latin pop", "classical pop", "pop-metal", "orchestral pop", "instrumental pop", "indie pop", "sophisti-pop", "pop punk", "pop reggae", "britpop", "traditional pop", "power pop", "sunshine pop", "baroque pop", "synthpop", "art pop", "teen pop", "psychedelic pop", "folk pop", "country pop", "pop rap", "pop soul", "pop and chart", "dance-pop", "pop", "top 40"]},
{"hip-hop/rnb": ["conscious hip hop", "east coast hip hop", "hardcore hip hop", "west coast hip hop", "hiphop", "southern hip hop", "hip-hop", "hip hop", "hip hop rnb and dance hall", "contemporary r b", "gangsta rap", "rapper", "rap", "rhythm and blues", "contemporary rnb", "contemporary r&b", "rnb", "rhythm & blues","r&b", "blues"]},
{"disco": ["disco"]},
{"swing":  ["swing"]},
{"folk": ["contemporary folk", "folk"]},
{"country": ["country rock", "country-pop", "country pop", "contemporary country", "country"]},
{"jazz": ["vocal jazz", "jazz", "jazz-rock"]},
{"religious": ["christian", "christmas music", "gospel"]},
{"blues": ["delta blues", "rock blues", "urban blues", "electric blues", "acoustic blues", "soul blues", "country blues", "jump blues", "classic rock. blues rock", "jazz and blues", "piano blues", "british blues", "british rhythm & blues", "rhythm and blues", "blues", "blues rock", "rhythm & blues"]},
{"reggae": ["reggae fusion", "roots reggae", "reggaeton", "pop reggae", "reggae", "soul and reggae"]}]

# %% [markdown]
# ### use cosine similarity to find aggregate genre per track
# There are 15 aggregated genres curated; based on each track's genre tags, we want to fuzzy match the track to 1 of the 15 aggregated genre tags

# %%
import math
from collections import Counter

def counter_cosine_similarity(c1, c2):
    terms = set(c1).union(c2)
    dotprod = sum(c1.get(k, 0) * c2.get(k, 0) for k in terms)
    magA = math.sqrt(sum(c1.get(k, 0)**2 for k in terms))
    magB = math.sqrt(sum(c2.get(k, 0)**2 for k in terms))
    return dotprod / (magA * magB)

# use below functions if you care about length of lists (do not think this is important)

def length_similarity(c1, c2):
    lenc1 = sum(c1.values())
    lenc2 = sum(c2.values())
    return min(lenc1, lenc2) / float(max(lenc1, lenc2))

def similarity_score(l1, l2):
    c1, c2 = Counter(l1), Counter(l2)
    return length_similarity(c1, c2) * counter_cosine_similarity(c1, c2)

# %% [markdown]
# ### create a series that assigns an 'aggregated genre' to each song track

# %%
list_of_genres = []

# iterate through each track
for track_tags in df_final_set['tags']:
    
    sim_counter = 0
    final_genre = 'N/A'
    
    if type(track_tags) is not float:
        if (len(track_tags) != 0):

            # iterate through each aggregated genre
            for genre in aggregate_genres:

                # pull genres associated with each aggregated genre
                for agg_genre, genres in genre.items():

                    # calculate cosine similarity between track tags vs. genres associated with aggregated genre
                    sim_temp = counter_cosine_similarity(Counter(track_tags), Counter(genres))

                    # if cosine similarity value is greater than counter, then update
                    if sim_counter < sim_temp:
                        sim_counter = sim_temp
                        final_genre = agg_genre

    # add aggregated genre to list
    list_of_genres.append(final_genre)

# %% [markdown]
# ### creating column 'agg_genre' in DataFrame

# %%
df_final_set['agg_genre'] = pd.Series(list_of_genres,index=df_final_set.index)

# %% [markdown]
# # Save/Load final dataframe here!

# %%
# pickle the final dataframe, removing songs without lyrics
#df_final_set.to_pickle("data/billboard_tracks_1950_2018_FINAL_v2.pkl")


# load dataframe, without audio features, but no missing lyrics
df_final_set = pd.read_pickle("data/billboard_tracks_1950_2018_FINAL_v2.pkl")
